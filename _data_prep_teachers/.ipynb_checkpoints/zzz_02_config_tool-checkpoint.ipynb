# %% [markdown]
# # Script to help user to define a configuration cell for ODC notebooks
#
# *****
#
# Geographical extent, time period, measurements, Coordinate Reference System (CRS) and resolution differ between the datasets available on the SDC.
#
# This script will help you to create a configuration cell to load the data that you want, to be manually copy/pasted or loaded in ODC Jupyter notebook. You also find the overview of all datasets on the website: https://explorer.swissdatacube.org/products, and you can view the "measurements.csv" file within this folder for information on the available datasets.

# %%
# Import modules

# reload module before executing code
# %load_ext autoreload
# %autoreload 2

import pyproj
import numpy as np
import ipywidgets as widgets
import dask.distributed
from pystac_client import Client
import ast
from shapely.geometry import Polygon
from odc.stac import stac_load
import matplotlib.pyplot as plt
from odc import loader
import odc
from pyproj import Proj, transform
import pandas as pd
from sdc_utilities import *


# silence warning (not recommended during development)
import warnings
warnings.filterwarnings("ignore")

# %%
# Connect to server
client = dask.distributed.Client()

# This connects to the server and downloads a "catalog" tha contains some metadata
# catalog = Client.open("https://explorer.swissdatacube.org/stac")
catalog = Client.open("https://explorer.digitalearth.africa/stac")

# Search the catalog for all available products
collections = catalog.get_collections()

# List the collections (products) available in the catalog
product_names = [collection.id for collection in collections]

descriptions = []
# Get the descriptions and print a full list
for pi in product_names:
    collection = catalog.get_collection(pi)
    descriptions.append(collection.description)
    # print(f"{collection.id} - {collection.description}")

df = pd.DataFrame({'products': product_names, 'description': descriptions})
print(df)
# Out:
#                    products                                        description
# 0        alos_palsar_mosaic  ALOS/PALSAR and ALOS-2/PALSAR-2 annual mosaic ...
# 1             cci_landcover           ESA Climate Change Initiative Land Cover
# 2            cgls_landcover  Copernicus Global Land Service, Land Use/Land ...
# 3     cgls_lwq100_2019_2024  Copernicus Global Land Service – Lake Water Qu...
# 4      cgls_lwq100_2024_nrt  Copernicus Global Land Service – Lake Water Qu...
# ..                      ...                                                ...
# 95  wofs_ls_summary_alltime   Water Observations from Space Alltime Statistics
# 96   wofs_ls_summary_annual    Water Observations from Space Annual Statistics
# 97                 wsf_2015  The World Settlement Footprint WSF 2015 versio...
# 98                 wsf_2019  The World Settlement Footprint (WSF) 2019 is a...
# 99            wsf_evolution  The World Settlement Footprint (WSF) Evolution...
#
# [100 rows x 2 columns]

# %% [markdown]
# # TESTS

# %%
# Connect to server
client = dask.distributed.Client()

# This connects to the server and downloads a "catalog" tha contains some metadata
# catalog = Client.open("https://explorer.swissdatacube.org/stac")
catalog = Client.open("https://explorer.digitalearth.africa/stac")

# Search the catalog for all available products
collections = catalog.get_collections()

# List the collections (products) available in the catalog
product_names = [collection.id for collection in collections]

# %%
catalog.description
# Out:
# 'Configure stac endpoint information in your Explorer `settings.env.py` file'

# %%
catalog.get_child("ndvi_anomaly")
# Out:
# <CollectionClient id=ndvi_anomaly>

# %%
collections = list(catalog.get_collections())

# %%
print(collections[72])
# Out:
# <CollectionClient id=ndvi_anomaly>

# %%
collections[72].links
child_links = [l for l in coll.links if l.rel == "child"]
child_links
child = Client.open(child_links[0].target)

# %%
child_links[0].target
# Out:
# 'https://explorer.digitalearth.africa/stac/catalogs/crop_mask/2019-1'

# %%
child
type(child)
# items = list(child.get_items())
# Out:
# pystac_client.client.Client

# %%
records = []

for coll in collections[72]:
    coll_id = coll#.id

    # Get all child links (e.g. yearly/monthly catalogs)
    child_links = [l for l in coll.links if l.rel == "child"]
    if not child_links:
        continue

    # Open first child catalog
    child = Client.open(child_links[0].target)

#     # Get first item (e.g. one tile of data)
#     items = list(child.get_items())
#     if not items:
#         continue

#     item = items[0]

#     # --- Extract projection info ---
#     epsg = item.properties.get("proj:epsg")
#     transform = item.properties.get("proj:transform")
#     shape = item.properties.get("proj:shape")
#     bbox = item.bbox

#     # Derive resolution from affine transform
#     if transform:
#         try:
#             aff = Affine(*transform)
#             xres, yres = abs(aff.a), abs(aff.e)
#         except Exception:
#             xres, yres = None, None
#     else:
#         xres, yres = None, None

#     records.append({
#         "product": coll_id,
#         "epsg": epsg,
#         "xres": xres,
#         "yres": yres,
#         "shape": shape,
#         "bbox": bbox
#     })

# # Combine into a dataframe
# df_meta = pd.DataFrame(records)
# pd.set_option("display.max_columns", None)
# print(df_meta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 records = []
# ----> 3 for coll in collections[72]:
#       4     coll_id = coll#.id
#       6     # Get all child links (e.g. yearly/monthly catalogs)
#
# TypeError: 'CollectionClient' object is not iterable

# %%
for coll in collections:
    print(f"\nCollection ID: {coll.id}")
    print(f"Description: {coll.description}")

    # Correct way to access summaries
    epsg = coll.summaries.get_list("proj:epsg")
    resolution = coll.summaries.get_list("proj:resolution")
    transform = coll.summaries.get_list("proj:transform")

    print("EPSG:", epsg)
    print("Resolution:", resolution)
    print("Transform:", transform)
    print("Bounding box:", coll.extent.spatial.bboxes)
# Out:
# Collection ID: alos_palsar_mosaic
# Description: ALOS/PALSAR and ALOS-2/PALSAR-2 annual mosaic tiles generated for use in the Data Cube - 25m pixel spacing, WGS84. These tiles are derived from the orignal JAXA mosaics with conversion to GeoTIFF.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-20.000000000000004, -35.019721543030116, 55.000000000000014, 39.99999999999999]]
#
# Collection ID: cci_landcover
# Description: ESA Climate Change Initiative Land Cover
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.361111111111054, -54.346951994584344, 64.50000000000004, 38.35000000000006]]
#
# Collection ID: cgls_landcover
# Description: Copernicus Global Land Service, Land Use/Land Cover at 100 m
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.36011904761957, -54.34760583154707, 64.49999999999922, 38.35019841269862]]
#
# Collection ID: cgls_lwq100_2019_2024
# Description: Copernicus Global Land Service – Lake Water Quality 2019-2024 (raster 100 m), global, 10-daily – version 1
#
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.844412504491498, -48.38593150343158, 58.70283866317457, 43.99478979518516]]
#
# Collection ID: cgls_lwq100_2024_nrt
# Description: Copernicus Global Land Service – Lake Water Quality 2024 - present (raster 100 m), global, 10-daily – version 2
#
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.844412504491498, -48.38593150343158, 68.65253323768988, 43.99478979518516]]
#
# Collection ID: cgls_lwq300_2002_2012
# Description: Copernicus Global Land Service – Lake Water Quality 2002-2012 (raster 300 m), global, 10-daily – version 1
#
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.845982142857036, -48.38729477228121, 58.703125002890246, 43.99553571434459]]
#
# Collection ID: cgls_lwq300_2016_2024
# Description: Copernicus Global Land Service – Lake Water Quality 2016-2024 (raster 300 m), global, 10-daily – version 1
#
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.845982142857036, -48.38729477232026, 58.70312499998195, 43.99553571428578]]
#
# Collection ID: cgls_lwq300_2024_nrt
# Description: Copernicus Global Land Service – Lake Water Quality 2024 - present (raster 300 m), global, 10-daily – version 2
#
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.845982142857036, -48.38729477232026, 58.70312499998195, 43.99553571428578]]
#
# Collection ID: crop_mask
# Description: Annual cropland extent map produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.909281977775752, -35.24826724976323, 58.70264648270937, 38.042047166442345]]
#
# Collection ID: crop_mask_central
# Description: Annual cropland extent map for Central Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[4.97480054938214, -18.372770346841786, 31.83872351604578, 13.67113232435786]]
#
# Collection ID: crop_mask_eastern
# Description: Annual cropland extent map for Eastern Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[28.853843186416487, -12.136659034777585, 48.753045383945086, 15.224049683998631]]
#
# Collection ID: crop_mask_indian_ocean
# Description: Annual cropland extent map for Indian Ocean Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[42.783284724686474, -25.664769163060623, 58.70264648270937, -11.359956112627579]]
#
# Collection ID: crop_mask_northern
# Description: Annual cropland extent map for Northern Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.909281977775752, 18.363930257728462, 35.81856395555151, 38.042047166442345]]
#
# Collection ID: crop_mask_sahel
# Description: Annual cropland extent map for Sahel Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.909281977775752, -2.258684619896017, 51.737925713574356, 27.338627325001042]]
#
# Collection ID: crop_mask_southeast
# Description: Annual cropland extent map for Southeast Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[21.88912241728146, -27.34200031301483, 41.78832461481009, -7.54630567704983]]
#
# Collection ID: crop_mask_southern
# Description: Annual cropland extent map for Southern Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[10.944561208640724, -35.24826724976323, 33.82864373579863, -16.78822055764781]]
#
# Collection ID: crop_mask_western
# Description: Annual cropland extent map for Western Africa produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-16.914321867899307, 3.7605099580112276, 14.924401648146446, 14.446269572091065]]
#
# Collection ID: dem_cop_30
# Description: Copernicus DEM 30 m
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.000138888888877, -47.00645814883983, 64.99986111111112, 39.00013888888891]]
#
# Collection ID: dem_cop_90
# Description: Copernicus DEM 90 m
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.000416666666656, -47.0061803687694, 64.99958333333335, 39.000416666666666]]
#
# Collection ID: dem_srtm
# Description: 1 second elevation model
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-32.000138888888884, -52.68355089186027, 61.00013888889554, 47.00013888888894]]
#
# Collection ID: dem_srtm_deriv
# Description: 1 second elevation model derivatives
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-32.00040453390067, -52.68338856102938, 60.99976063638659, 47.00037607404329]]
#
# Collection ID: esa_worldcereal_activecropland
# Description: ESA WorldCereal 10m 2021 v1.0.0 active cropland map for the main cereals season defined in a region (tc-wintercereals).
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.000189019221324, -36.697771594044845, 59.99502963949722, 45.153837250427806]]
#
# Collection ID: esa_worldcereal_maize_active
# Description: ESA WorldCereal 10m 2021 v1.0.0 active cropland map for the main maize season defined in a region (tc-maize-main).
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.000189019221324, -36.697771594044845, 59.99502963949722, 45.153837250427806]]
#
# Collection ID: esa_worldcereal_maize_irrigation
# Description: ESA WorldCereal 10m 2021 v1.0.0 irrigation map for the main maize season defined in a region (tc-maize-main).
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.991847872575384, -36.69781037011635, 59.99502963949722, 45.15383725042775]]
#
# Collection ID: esa_worldcereal_maize_main
# Description: ESA WorldCereal 10m 2021 v1.0.0 maize crop map for main maize season defined in a region.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.000189019221324, -36.69781037011635, 59.99502963949722, 45.15383725042775]]
#
# Collection ID: esa_worldcereal_temporarycrops
# Description: ESA WorldCereal 10m 2021 v1.0.0 temporary crops map for the 2021 tc-annual season.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.754676710360744, -36.697853167410365, 59.99509950815737, 45.15383725042775]]
#
# Collection ID: esa_worldcereal_wintercereals
# Description: ESA WorldCereal 10m 2021 v1.0.0 wintercereals crop map for the main cereals season defined in a region (tc-wintercereals).
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.754676710360744, -36.697853167410365, 59.995029639497204, 45.15383725042775]]
#
# Collection ID: esa_worldcereal_wintercereals_irrigation
# Description: ESA WorldCereal 10m 2021 v1.0.0 irrigation map for the main cereals season defined in a region (tc-wintercereals).
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.991847872575384, -36.697853167410365, 59.995029639497204, 45.15383725042775]]
#
# Collection ID: esa_worldcover
# Description: ESA World Cover, global 10 m land use/land cover data from 2020.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: esa_worldcover_2020
# Description: ESA World Cover, global 10 m land use/land cover data from 2020.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.0, -48.00660699412118, 66.00000000000003, 39.00000000000008]]
#
# Collection ID: esa_worldcover_2021
# Description: ESA World Cover, global 10 m land use/land cover data from 2021.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.0, -48.00660699412118, 66.00000000000003, 39.00000000000008]]
#
# Collection ID: fc_ls
# Description: Landsat Fractional Cover Observations from Space
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-28.210834894981158, -49.84287001157945, 65.5742013430175, 40.715741992688386]]
#
# Collection ID: fc_ls_summary_annual
# Description: DE Africa Landsat Fractional Cover Percentiles
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.858883076539954, -50.61475737951068, 65.66736725184441, 40.95209644125588]]
#
# Collection ID: gm_ls5_ls7_annual
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Landsat 5 and Landsat 7
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663612, -49.448744175792136, 64.67240714196795, 40.95209644125588]]
#
# Collection ID: gm_ls5_ls7_annual_lowres
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Landsat 5 and Landsat 7. Low resolution version used for visualisations.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663715, -55.940081457191, 64.67240714196797, 40.95209644125588]]
#
# Collection ID: gm_ls8_annual
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Landsat 8
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663612, -49.448744175792136, 64.67240714196797, 39.96862231589367]]
#
# Collection ID: gm_ls8_annual_lowres
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Landsat 8. Low resolution version used for visualisations.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663715, -55.940081457191, 64.67240714196797, 39.96862231589358]]
#
# Collection ID: gm_ls8_ls9_annual
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Landsat 8 and Landsat 9
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663612, -49.448744175792136, 65.66736725184441, 39.96862231589358]]
#
# Collection ID: gm_ls8_ls9_annual_lowres
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Landsat 8 and Landsat 9. Low resolution version used for visualisations.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663715, -56.08708306191742, 65.66736725184442, 39.96862231589358]]
#
# Collection ID: gm_s2_annual
# Description: Surface Reflectance Annual Geometric Median and Median Absolute Deviations, Sentinel-2
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.85888307654003, -48.321570838759705, 65.66736725184437, 38.9988828990037]]
#
# Collection ID: gm_s2_annual_lowres
# Description: Annual Geometric Median, Sentinel-2 - Low Resolution mosaic
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-33.74999999754783, -56.91830508966366, 67.50000000407869, 40.98197154308616]]
#
# Collection ID: gm_s2_rolling
# Description: Surface Reflectance 3 Monthly Rolling Geometric Median and Median Absolute Deviations, Sentinel-2
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.858883076539954, -48.321570838759705, 65.6673672518444, 38.99888289900376]]
#
# Collection ID: gm_s2_semiannual
# Description: Surface Reflectance Semiannual Geometric Median and Median Absolute Deviations, Sentinel-2
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.85888307654003, -48.321570838759705, 65.66736725184437, 38.99888289900376]]
#
# Collection ID: gm_s2_semiannual_lowres
# Description: Surface Reflectance Semiannual Geometric Median and Median Absolute Deviations, Sentinel-2. Low resolution version used for visualisations.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.858883076540057, -55.08263651708101, 65.66736725184438, 38.99888289900376]]
#
# Collection ID: gmw
# Description: Global Mangrove Watch data sourced from the UN Environment Program at https://data.unep-wcmc.org/datasets/45
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.35999999999999, -54.347348820011, 64.50000000000001, 38.349999999999994]]
#
# Collection ID: io_lulc
# Description: Impact Observatory (ESRI) Landcover Classification 9 Class
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: io_lulc_v2
# Description: Impact Observatory (ESRI) Landcover Classification 9 Class V2
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-30.319549419467577, -56.023086787198004, 66.31954941946765, 39.991197939844575]]
#
# Collection ID: isda_soil_bedrock_depth
# Description: Soil bedrock depth predictions made by iSDA Africa
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-31.464238427972045, -41.17327724158084, 57.08171098087664, 37.649808972158255]]
#
# Collection ID: isda_soil_bulk_density
# Description: Soil bulk density predictions made by iSDA Africa
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-31.464238427972045, -41.17327724158084, 57.08171098087664, 37.649808972158255]]
#
# Collection ID: isda_soil_carbon_total
# Description: Soil total carbon predictions made by iSDA Africa
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-31.464238427972045, -41.17327724158084, 57.08171098087664, 37.649808972158255]]
#
# Collection ID: isda_soil_clay_content
# Description: Soil clay content predictions made by iSDA Africa
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-31.464238427972045, -41.17327724158084, 57.08171098087664, 37.649808972158255]]
#
# Collection ID: isda_soil_sand_content
# Description: Soil sand content predictions made by iSDA Africa
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-31.464238427972045, -41.17327724158084, 57.08171098087664, 37.649808972158255]]
#
# Collection ID: isda_soil_silt_content
# Description: Soil silt content predictions made by iSDA Africa
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-31.464238427972045, -41.17327724158084, 57.08171098087664, 37.649808972158255]]
#
# Collection ID: iwmi_blue_et_monthly
# Description: Monthly Incremental Evapotranspiration (ET) for Africa from the Water Accounting Plus project.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.532159805297784, -38.631715104079646, 51.42671966552737, 37.34130859375004]]
#
# Collection ID: iwmi_evaporation_monthly
# Description: Loss of water from soil, water bodies, and surfaces to the atmosphere as vapor.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.532159805297784, -38.631715104079646, 51.42671966552737, 37.34130859375004]]
#
# Collection ID: iwmi_green_et_monthly
# Description: Monthly Rainfall Evapotranspiration (ET) for Africa from the Water Accounting Plus project.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.532159805297784, -38.631715104079646, 51.42671966552737, 37.34130859375004]]
#
# Collection ID: iwmi_interception_monthly
# Description: Rainfall captured by plant surfaces (leaves, branches, stems) that evaporates before reaching the ground or soil.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: iwmi_transpiration_monthly
# Description: Water loss from plants through stomata into the atmosphere.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-17.532159805297784, -38.631715104079646, 51.42671966552737, 37.34130859375004]]
#
# Collection ID: jers_sar_mosaic
# Description: JERS-1 SAR annual mosaic tiles generated for use in the Data Cube 25m pixel spacing, WGS84. These tiles are derived from the orignal JAXA mosaics with conversion to GeoTIFF.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.000000000000064, -35.019721543030116, 55.000000000000014, 40.00000000000004]]
#
# Collection ID: landsat_c2l2_ar
# Description: USGS Landsat Collection 2 Level-2 Provisional Aquatic Reflectance
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.376244059937527, 10.51832383819841, -14.37802487448816, 16.941146573289004]]
#
# Collection ID: ls5_sr
# Description: USGS Landsat 5 Collection 2 Level-2 Surface Reflectance
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.023775750537155, -45.59437400509199, 60.73111329727358, 40.715741992688386]]
#
# Collection ID: ls5_st
# Description: USGS Landsat 5 Collection 2 Level-2 Surface Temperature
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.583289572579158, -35.67835868642331, 57.887682977836796, 40.715741992688386]]
#
# Collection ID: ls7_sr
# Description: USGS Landsat 7 Collection 2 Level-2 Surface Reflectance
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.03571045762493, -49.84287001157945, 65.5742013430175, 39.914187504303804]]
#
# Collection ID: ls7_st
# Description: USGS Landsat 7 Collection 2 Level-2 Surface Temperature
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-20.013713916952188, -35.58496019876811, 57.83535271225737, 39.914187504303804]]
#
# Collection ID: ls8_sr
# Description: USGS Landsat 8 Collection 2 Level-2 Surface Reflectance
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-28.210834894981158, -48.51661356705256, 65.30179309473174, 39.9556558750373]]
#
# Collection ID: ls8_st
# Description: USGS Landsat 8 Collection 2 Level-2 Surface Temperature
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.519990618279873, -35.666021077205464, 57.59170257030979, 39.9556558750373]]
#
# Collection ID: ls9_sr
# Description: USGS Landsat 9 Collection 2 Level-2 Surface Reflectance
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-28.200769210062724, -48.51346463077324, 65.02372432108355, 39.95196709203219]]
#
# Collection ID: ls9_st
# Description: USGS Landsat 9 Collection 2 Level-2 Surface Temperature
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.37624405993745, -35.66325437945106, 57.584811979880705, 39.95196709203219]]
#
# Collection ID: maxar_morocco_earthquake
# Description: Maxar data related to the Morocco Earthquake event in September 2023.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: maxar_morocco_earthquake_4bands
# Description: Maxar data related to the Morocco Earthquake event in September 2023, collected by GeoEye-1 and WorldView-4 satellites
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: maxar_morocco_earthquake_8bands
# Description: Maxar data related to the Morocco Earthquake event in September 2023, collected by WorldView-1 and WorldView-2 satellites
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: nasadem
# Description: NASADEM from Microsoft's Planetary Computer
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-28.000138890000013, -47.00673696949906, 66.00013889000003, 40.00013889000004]]
#
# Collection ID: ndvi_anomaly
# Description: Monthly NDVI Anomalies produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-24.87400274691075, -35.24826724976323, 51.737925713574356, 38.042047166442345]]
#
# Collection ID: ndvi_climatology_ls
# Description: Monthly NDVI Climatologies produced by Digital Earth Africa.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-24.87400274691075, -35.24826724976325, 51.737925713574356, 38.042047166442345]]
#
# Collection ID: pc_s2_annual
# Description: Surface Reflectance Annual Clear Pixel Count, Sentinel-2
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.85888307654003, -48.321570838759705, 65.66736725184437, 38.99888289900376]]
#
# Collection ID: rainfall_chirps_daily
# Description: Rainfall Estimates from Rain Gauge and Satellite Observations
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-19.99999999999995, -44.38333947917845, 55.00000111758713, 40.00000000000004]]
#
# Collection ID: rainfall_chirps_monthly
# Description: Rainfall Estimates from Rain Gauge and Satellite Observations
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-20.000000000000004, -44.38333947917845, 55.00000111758713, 40.00000000000004]]
#
# Collection ID: s1_monthly_mosaic
# Description: Monthly Sentinel-1 mosaics of weighted terrain-corrected backscatter.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.00018719431749, -51.445793914516024, 73.15100812295492, 40.65085651460241]]
#
# Collection ID: s1_rtc
# Description: Sentinel 1 Gamma0 normalised radar backscatter
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.763023938311118, -48.00281853375911, 60.41794532845591, 39.00000000000008]]
#
# Collection ID: s2_l2a
# Description: Sentinel-2a and Sentinel-2b imagery, processed to Level 2A (Surface Reflectance) and converted to Cloud Optimized GeoTIFFs
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.0001795682511, -47.75139377349789, 65.01057950198401, 38.848989471816836]]
#
# Collection ID: s2_l2a_c1
# Description: ESA Sentinel-2A and Sentinel-2B Collection 1 Level-2A Surface Reflectance
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-27.0001795682511, -47.75139377349789, 64.72940530420738, 38.8489984833856]]
#
# Collection ID: s3_ol_2_wfr_nrt
# Description: Sentinel-3 Level 2 Water Full Resolution (WFR) products in Near Real Time (NRT)
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s3_olci_l2_lfr
# Description: Sentinel-3 OLCI L2 LAND
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-28.73006959022132, -52.13579413277508, 80.97342979803175, 40.18189916902102]]
#
# Collection ID: s3_olci_l2_wfr
# Description: Sentinel-3 OLCI L2 WATER
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s3_syn_2_vg1
# Description: Sentinel-3 Level-2 VG1 SYN product
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_aer_ai
# Description: Sentinel-5p TROPOMI Level 2 UV Aerosol Index.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_ch4
# Description: Sentinel-5p TROPOMI Level 2 Methane (CH4) total column.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_cloud
# Description: Sentinel-5p TROPOMI Level 2 Cloud fraction, albedo, top pressure.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_co
# Description: Sentinel-5p TROPOMI Level 2 Carbon Monoxide (CO) total column.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_hcho
# Description: Sentinel-5p TROPOMI Level 2 Formaldehyde (HCHO) total column.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_no2
# Description: Sentinel-5p TROPOMI Level 2 Nitrogen Dioxide (NO2), total and tropospheric columns.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_o3
# Description: Sentinel-5p TROPOMI Level 2 Ozone (O3) total column.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: s5p_tropomi_l2_so2
# Description: Sentinel-5p TROPOMI Level 2 Sulfur Dioxide (SO2) total column.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-180.0, -90.0, 180.0, 90.0]]
#
# Collection ID: wapor_soil_moisture
# Description: WaPOR v3 Level 2 100m dekadal relative root zone soil moisture.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[180.0, -59.99999999999989, 180.0, 60.00000000000007]]
#
# Collection ID: wofs_ls
# Description: Historic Flood Mapping Water Observations from Space
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-28.210834894981158, -49.84287001157945, 65.5742013430175, 40.715741992688386]]
#
# Collection ID: wofs_ls_summary_alltime
# Description: Water Observations from Space Alltime Statistics
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663562, -49.4487441757921, 65.66736725184441, 40.95209644125588]]
#
# Collection ID: wofs_ls_summary_annual
# Description: Water Observations from Space Annual Statistics
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.863922966663562, -49.4487441757921, 65.66736725184441, 40.95209644125588]]
#
# Collection ID: wsf_2015
# Description: The World Settlement Footprint WSF 2015 version 2 (WSF2015 v2) is a 10m resolution binary maskoutlining the extent of human settlements globally for the year 2015 based on multiple datasets.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.010000399453457, -48.012919305242626, 64.0100843906354, 38.010055290835645]]
#
# Collection ID: wsf_2019
# Description: The World Settlement Footprint (WSF) 2019 is a 10m resolution binary mask outlining the extent of human settlements globally derived by means of 2019 multitemporal Sentinel-1 (S1) and Sentinel-2 (S2) imagery.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.010000399453457, -48.012919305242626, 64.0100843906354, 38.010055290835645]]
#
# Collection ID: wsf_evolution
# Description: The World Settlement Footprint (WSF) Evolution is a 30m resolution dataset derived from Landsat-5/7 outlining the global settlement extent on a yearly basis from 1985 to 2015.
# EPSG: None
# Resolution: None
# Transform: None
# Bounding box: [[-26.010000399453457, -48.01309896441366, 64.01008439063538, 38.010055290835645]]

# %%
for coll in collections:
    print(f"\n{coll.id}")
    print("EPSG:", coll.summaries.get("proj:epsg"))
    print("Resolution:", coll.summaries.get("proj:shape"))
    print("BBox:", coll.extent.spatial.bboxes)
# Out:
# alos_palsar_mosaic
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 3
#       1 for coll in collections:
#       2     print(f"\n{coll.id}")
# ----> 3     print("EPSG:", coll.summaries.get("proj:epsg"))
#       4     print("Resolution:", coll.summaries.get("proj:shape"))
#       5     print("BBox:", coll.extent.spatial.bboxes)
#
# AttributeError: 'Summaries' object has no attribute 'get'

# %%
for coll in collections:
    print(coll.links)
    # child_links = [link for link in coll.links if link.rel == "child"]
    # print(child_links)

# %%
child_links
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 child_links
#
# NameError: name 'child_links' is not defined

# %%
child_links = [link for link in coll.links if link.rel == "child"]

# %%
# import pandas as pd

# data = []

# for pi in product_names:
#     collection = catalog.get_collection(pi)
#     for coll in collections:
#         print(coll.id)
#         name = coll.id
#         child_links = [link for link in coll.links if link.rel == "child"]
#         if not child_links:
#             continue
    
#         # open first child (to avoid huge loops)
#         child = catalog.open(child_links[0].target)
#         items = list(child.get_items())
#         if not items:
#             continue
    
#         item = items[0]
    
#         epsg = item.properties.get("proj:epsg")
#         bbox = item.bbox
#         shape = item.properties.get("proj:shape")
#         transform = item.properties.get("proj:transform")
    
#         data.append({
#             "product": name,
#             "epsg": epsg,
#             "bbox": bbox,
#             "shape": shape,
#             "transform": transform
#         })
    
# df_meta = pd.DataFrame(data)
# print(df_meta)

# %%
# collection
collection = catalog.get_collection("ndvi_anomaly")
collection.links
# for c in collection:
#     c.child
# Out:
# [<Link rel=root target=<Client id=DEAfrica_data>>,
#  <Link rel=self target=https://explorer.digitalearth.africa/stac/collections/ndvi_anomaly>,
#  <Link rel=items target=https://explorer.digitalearth.africa/stac/collections/ndvi_anomaly/items>,
#  <Link rel=http://www.opengis.net/def/rel/ogc/1.0/queryables target=https://explorer.digitalearth.africa/stac/collections/ndvi_anomaly/queryables>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2017-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2018-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2019-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2020-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2021-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2022-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2023-12>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-9>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-10>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2024-11>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-1>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-2>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-3>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-4>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-5>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-6>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-7>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-8>,
#  <Link rel=child target=https://explorer.digitalearth.africa/stac/catalogs/ndvi_anomaly/2025-9>]

# %%
# # The full list:
# for row_i in range(df.shape[0]):
#     print(df.iloc[row_i,0] + ' --- ' + df.iloc[row_i,1])

# %%
# Allow user to select an available product prioritizing ingested (if any)over indexed

# Select the product
product_sel = widgets.RadioButtons(options=product_names, disabled=False)
display(widgets.Label('Select a product and run the next cell: '), product_sel)
# Out:
# Label(value='Select a product and run the next cell: ')
# RadioButtons(options=('alos_palsar_mosaic', 'cci_landcover', 'cgls_landcover', 'cgls_lwq100_2019_2024', 'cgls_…

# %%
# somewhere the function str is getting assigned as new variable. not sure where. just reset it.
if not isinstance(str, type) or str.__name__ != 'str':
    # Restore the built-in str function
    del str

ds_selected = product_sel.value
df = pd.read_csv("measurements.csv")
dfs = df.loc[df['product']==ds_selected]
resolution = (-1*dfs['resolution'].min(),dfs['resolution'].min())

no_dates_str = 'No date infromation available. Visit https://explorer.swissdatacube.org/products for more information. You can leave the date also out for now.'
try:
    date_start = pd.to_datetime(dfs['time_start']).min()
except: 
    print(no_dates_str)
try:
    date_end = pd.to_datetime(dfs['time_end']).max()
except: 
    print(no_dates_str)

if date_start and date_end:
    time = (date_start.strftime('%Y-%m-%d'), date_end.strftime('%Y-%m-%d'))
# measurements_aliases = ['QA_PIXEL', 'blue', 'green', 'red', 'nir', 'swir_1', 'swir_2']
out = {}
aliases_ = {}
for r in range(len(dfs.index)):
    # r['measurement']
    _alias = dfs.iloc[r,:]['aliases']
    _alias = ast.literal_eval(_alias)
    _meas = dfs.iloc[r,:]['measurement']
    out[r] = _meas + ': ' + str(_alias)
    aliases_[r] = _alias[-1]

df = pd.DataFrame(list(out.values()), columns=['Bands'])

measur_sel = widgets.SelectMultiple(options=sorted(list(df['Bands'])),disabled=False)
display(widgets.Label('Select measurements (displayed with their aliases) and run the next cell: '), measur_sel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 22
#      19     print(no_dates_str)
#      21 if date_start and date_end:
# ---> 22     time = (date_start.strftime('%Y-%m-%d'), date_end.strftime('%Y-%m-%d'))
#      23 # measurements_aliases = ['QA_PIXEL', 'blue', 'green', 'red', 'nir', 'swir_1', 'swir_2']
#      24 out = {}
#
# File pandas/_libs/tslibs/nattype.pyx:54, in pandas._libs.tslibs.nattype._make_error_func.f()
#
# ValueError: NaTType does not support strftime

# %%
# Convert selection to measurements list and message 

measur_list = list(measur_sel.value)

measur_sel = []
alias_sel = []
msg = '# to make your live easier you can manually replace the measurements variable by \n' \
      '# one of their alias:\n'
# cnt = 0
for m in measur_list:
    str_1 = m.split(': ')[0]
    str_2 = ast.literal_eval(m.split(': ')[1])[-1]
    measur_sel.append(str_1)
    if str_1 == "QA_PIXEL" or str_1 == "SCL":
        alias_sel.append(str_1)
    else:
        alias_sel.append(str_2)
    # cnt +=1

print(f"Using the following measurements {measur_sel}")
print(f"Corresponding to the aliases     {alias_sel}")
# Out:
# Using the following measurements ['SR_B2', 'SR_B3']
# Corresponding to the aliases     ['green', 'red']

# %% [markdown]
# ## Defining spatial extent
#
# Open the website https://geojson.io/ and make your selection using the "rectangle" selection tool. The coordinates pop up on the right-hand side. Select the min and max values for the latitude and longitude. In the example this would be:
#
# ```
# longitude =  (7.127, 7.199)
# latitude =  (46.773, 46.816)
# ```
#
# Choose a <span style="color:red; font-size: 20px">***very small area*** </span>to test your workflow first, like in the example below.
#
# Once you identified your bounding box (coordinates), add this into the cell below.
#
# ![geojson.io example](https://www.dropbox.com/scl/fi/9b93k2tsmk9u3nw2e3n0l/geojson.jpeg?rlkey=k5o3axx60eddd5nv58dx50bij&dl=1)

# %%
product = ds_selected
measurements = measur_sel

# Only change the extent in the following two lines :
longitude =  (7.127, 7.199) 
latitude =  (46.773, 46.816)
#  --------------------------------------------------

crs = 'epsg:4326'  # This is lat/lon geographic coordinates

# It makes sense to use a projected coordinates system for analysis related to areas and at high latitudes (Switzerland already above 45 degrees North)
output_crs = 'epsg:2056'   # (https://epsg.io/2056)

# You can define the final resolution. The original resolution is already stored in the variable "resolution". You can check it by making a new cell above and calling that variable
# resolution = -100.0, 100.0

# %%
# Select time period

start_date = widgets.DatePicker(description='Start date',
                                value = date_start.date(),
                                disabled=False)
end_date = widgets.DatePicker(description='End date',
                              value = date_end.date(),
                              disabled=False)
display(widgets.Label('IF REQUIRED define time period (cannot be outside of the initial displayed time) and run the next cell:'),
        widgets.HBox([start_date, end_date]))
# Out:
# Label(value='IF REQUIRED define time period (cannot be outside of the initial displayed time) and run the next…
# HBox(children=(DatePicker(value=datetime.date(1999, 6, 1), description='Start date', step=1), DatePicker(value…

# %%
# Check defined time period

assert start_date.value >= date_start.date(), \
       'Start date cannot be defined before {}'.format(date_start.date())
assert end_date.value <= date_end.date(), \
       'End date cannot be defined after {}'.format(date_end.date())
assert start_date.value <= end_date.value, \
       'End date is defined before start date'

# end_date = end_date.value + timedelta(days=1) # end_date is not inclusive !

print('Time period is OK')
# Out:
# Time period is OK

# %%
##### Resume configuration parameters in a format ready to be copy/pasted to a new cell,
# and in a txt file to be loaded with the '%load config_cell.txt' magic.

str = f'''# Configuration

product = '{product_sel.value}'
measurements = {measur_sel}
aliases = {alias_sel}  # you can also provide only the aliases and get the measurements with:
# measurements, aliases = get_alias_band(aliases)
{msg}
longitude = ({longitude[0]}, {longitude[1]})
latitude = ({latitude[0]}, {latitude[1]})
crs = 'epsg:4326'

time = ('{start_date.value.strftime('%Y-%m-%d')}', '{end_date.value.strftime('%Y-%m-%d')}')
# the following date formats are also valid:
# time = ('2000-01-01', '2001-12-31')
# time=('2000-01', '2001-12')
# time=('2000', '2001')

# You can use an UTM zone according to the DataCube System.
# We prefer not to use this, instead specifying SwissGrid (epsg:2056).
# output_crs = 'epsg:2056'

output_crs = '{output_crs}'
resolution = {resolution[0]}, {resolution[1]}

# These are the pixel classifications for Sentinel (SCL) and Landsat (QA_PIXEL); 
# you can use values to mask out values that belong to certain classes

###################################
# SCL categories:                 #
#   0 - no data                   #
#   1 - saturated or defective    #
#   2 - dark area pixels          #
#   3 - cloud_shadows             #
#   4 * vegetation                #
#   5 * not vegetated             #
#   6 * water                     #
#   7 * unclassified              #
#   8 - cloud medium probability  #
#   9 - cloud high probability    #
#  10 - thin cirrus               #
#  11 * snow                      #
###################################

# Check for more detailed information: 
# - Landsat 8/9 (OLI/TIRS), Page 19:
# https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/media/files/LSDS-1619_Landsat8-9-Collection2-Level2-Science-Product-Guide-v6.pdf
# - Landsat 7 (ETM+), Page 15:
# https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/media/files/LSDS-1337_Landsat7ETM-C2-L2-DFCB-v6.pdf
# - Landsat 4,5 (TM), Page 18:
# https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/atoms/files/LSDS-1415_Landsat4-5-TM-C2-L1-DFCB-v3.pdf

#############################################
# QA_PIXEL BITS : CATEGORIES                #
#    0 : Fill                               #
#    1 : Clear                              #
#    2 : Water                              #
#    3 : Cloud shadow                       #
#    4 : Snow                               #
#    5 : Cloud                              #
#   10 : Terrain occlusion (Landsat 8 only) #
#############################################

chunks = {{"x": 2048, "y": 2048, "time": 1}}  # 2048 values are OK with ~21Gb memory available
'''
print(str)
with open('config_cell.txt', 'w') as text_file:
    print(str, file=text_file)
# Out:
# # Configuration
#
# product = 'landsat_etm_c2_l2'
# measurements = ['SR_B2', 'SR_B3']
# aliases = ['green', 'red']  # you can also provide only the aliases and get the measurements with:
# # measurements, aliases = get_alias_band(aliases)
# # to make your live easier you can manually replace the measurements variable by
# # one of their alias:
#
# longitude = (7.127, 7.199)
# latitude = (46.773, 46.816)
# crs = 'epsg:4326'
#
# time = ('1999-06-01', '2023-10-01')
# # the following date formats are also valid:
# # time = ('2000-01-01', '2001-12-31')
# # time=('2000-01', '2001-12')
# # time=('2000', '2001')
#
# # You can use an UTM zone according to the DataCube System.
# # We prefer not to use this, instead specifying SwissGrid (epsg:2056).
# # output_crs = 'epsg:2056'
#
# output_crs = 'epsg:2056'
# resolution = -30.0, 30.0
#
# # These are the pixel classifications for Sentinel (SCL) and Landsat (QA_PIXEL);
# # you can use values to mask out values that belong to certain classes
#
# ###################################
# # SCL categories:                 #
# #   0 - no data                   #
# #   1 - saturated or defective    #
# #   2 - dark area pixels          #
# #   3 - cloud_shadows             #
# #   4 * vegetation                #
# #   5 * not vegetated             #
# #   6 * water                     #
# #   7 * unclassified              #
# #   8 - cloud medium probability  #
# #   9 - cloud high probability    #
# #  10 - thin cirrus               #
# #  11 * snow                      #
# ###################################
#
# # Check for more detailed information:
# # - Landsat 8/9 (OLI/TIRS), Page 19:
# # https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/media/files/LSDS-1619_Landsat8-9-Collection2-Level2-Science-Product-Guide-v6.pdf
# # - Landsat 7 (ETM+), Page 15:
# # https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/media/files/LSDS-1337_Landsat7ETM-C2-L2-DFCB-v6.pdf
# # - Landsat 4,5 (TM), Page 18:
# # https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/atoms/files/LSDS-1415_Landsat4-5-TM-C2-L1-DFCB-v3.pdf
#
# #############################################
# # QA_PIXEL BITS : CATEGORIES                #
# #    0 : Fill                               #
# #    1 : Clear                              #
# #    2 : Water                              #
# #    3 : Cloud shadow                       #
# #    4 : Snow                               #
# #    5 : Cloud                              #
# #   10 : Terrain occlusion (Landsat 8 only) #
# #############################################
#
# chunks = {"x": 2048, "y": 2048, "time": 1}  # 2048 values are OK with ~21Gb memory available
